# %%
# %%writefile templates/upload.html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Resume Upload Portal</title>
#
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             background: linear-gradient(to right, #4158D0, #C850C0, #FFCC70);
#             height: 100vh;
#             margin: 0;
#             display: flex;
#             justify-content: center;
#             align-items: center;
#         }
#
#         .container {
#             background: #ffffffdd;
#             backdrop-filter: blur(5px);
#             padding: 40px;
#             width: 700px;
#             border-radius: 15px;
#             text-align: center;
#             box-shadow: 0px 6px 20px rgba(0,0,0,0.2);
#         }
#
#         h2 {
#             margin-bottom: 20px;
#             font-size: 26px;
#             color: #333;
#         }
#
#         .upload-box {
#             border: 2px dashed #6a11cb;
#             padding: 20px;
#             border-radius: 10px;
#             margin-bottom: 20px;
#             cursor: pointer;
#             transition: 0.3s;
#             color: #555;
#         }
#
#         .upload-box:hover {
#             border-color: #2575fc;
#             background: #f1f1f1;
#         }
#
#         input[type="file"] {
#             width: 100%;
#             cursor: pointer;
#         }
#
#         button {
#             background-color: #6a11cb;
#             color: white;
#             padding: 12px 25px;
#             border: none;
#             border-radius: 8px;
#             font-size: 16px;
#             cursor: pointer;
#             transition: 0.3s;
#         }
#
#         button:hover {
#             background-color: #2575fc;
#             transform: scale(1.05);
#         }
#
#         .footer-text {
#             margin-top: 10px;
#             font-size: 13px;
#             color: #333;
#         }
#     </style>
# </head>
#
# <body>
#     <div class="container">
#         <h2>Upload Your Resume</h2>
#
#         <form action="/upload" method="POST" enctype="multipart/form-data">
#             <label class="upload-box">
#                 <input type="file" name="resume" required>
#                 <p>Click here to choose resume (PDF only)</p>
#             </label>
#
#             <button type="submit">Upload File</button>
#         </form>
#
#         <p class="footer-text">Your resume will be processed automatically.</p>
#     </div>
# </body>
# </html>
# Out:
# Overwriting templates/upload.html

# %%
from flask import Flask, render_template, request
import os

app = Flask(__name__)

UPLOAD_FOLDER = "pdf_files"  
os.makedirs(UPLOAD_FOLDER, exist_ok=True)

@app.route("/")
def index():
    return render_template("upload.html")

@app.route("/upload", methods=["POST"])
def upload_file():
    if "resume" not in request.files:
        return " No file part"

    file = request.files["resume"]

    if file.filename == "":
        return "No selected file"

    save_path = os.path.join(UPLOAD_FOLDER, file.filename)
    file.save(save_path)

    print("File uploaded to:", save_path)
    return "File uploaded successfully!"

# %%
# !python app.py

# %%
from IPython.display import IFrame
IFrame(src="http://127.0.0.1:5000", width=900, height=500)
